# %%
# !python -m jupytext --to ipynb regime_analysis.py
# Out:
# [jupytext] Reading regime_analysis.py in format py
# [jupytext] Writing regime_analysis.ipynb

# %%
# !python -m jupytext --to ipynb regime_metrics_states.py
# Out:
# [jupytext] Reading regime_metrics_states.py in format py
# [jupytext] Writing regime_metrics_states.ipynb

# %%
# !python -m jupytext --to ipynb ETF_SAA_DR_RSDR_CVaR_Analysis_formula_explained.py
# Out:
# [jupytext] Reading ETF_SAA_DR_RSDR_CVaR_Analysis_formula_explained.py in format py
# [jupytext] Writing ETF_SAA_DR_RSDR_CVaR_Analysis_formula_explained.ipynb

# %%
# !python -m jupytext --to ipynb integrated_regime_pipeline.py
# Out:
# [jupytext] Reading integrated_regime_pipeline.py in format py
# [jupytext] Writing integrated_regime_pipeline.ipynb
# [jupytext] Updating the timestamp of integrated_regime_pipeline.py
