# %%
## Version Control: Python 3.13.5

import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import pathlib
from pathlib import Path

# %%
## This is for Daily Data. You may need to change it for monthly data

data = pd.read_csv("Farma_French/F-F_Research_Data_5_Factors_2x3_US_daily.CSV", index_col=0, skiprows = 3)  # Skip the first 3 rows of metadata
data = data[:-1]                                                                                            # Remove the last row which contains metadata

data.index = pd.to_datetime(data.index, format="%Y%m%d")

# %%
data.tail()
# Out:
#             Mkt-RF   SMB   HML   RMW   CMA    RF
# 2026-04-24    0.70 -0.28 -0.28 -1.16 -0.55  0.01
# 2026-04-27    0.10  0.07  0.62  0.56 -0.80  0.01
# 2026-04-28   -0.57 -0.21  0.88  1.03  0.52  0.01
# 2026-04-29   -0.13 -1.30  0.53 -0.72  0.23  0.01
# 2026-04-30    1.13  0.79 -0.71 -0.97  0.56  0.01
